# %%
# !pip install faker
# !pip install confluent_kafka

# %%
import time
from faker import Faker
from confluent_kafka import Producer
import json

fake = Faker()

bootstrap_servers = 'pkc-7xoy1.eu-central-1.aws.confluent.cloud:9092'
sasl_plain_username = 'USERNAME'
sasl_plain_password = 'SECRET'
topic_name = 'Traffic_Updates'

# Create the Kafka producer
producer_config = {
    'bootstrap.servers': bootstrap_servers,
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': sasl_plain_username,
    'sasl.password': sasl_plain_password,
}

producer = Producer(producer_config)


def delivery_report(err, msg):
    if err is not None:
        print('Message delivery failed: {}'.format(err))
    else:
        print('Message delivered to topic {} [partition {}] at offset {}'.format(msg.topic(), msg.partition(), msg.offset()))


def get_registered_users():
    return {
        # "name": fake.name(),
        # "address": fake.address(),
        # "message": fake.text(),
        # "created_on": fake.year()

        "timestamp": fake.date_time_this_year().isoformat(),
        "location": fake.random_element(elements=("A", "B", "C", "D")),
        "speed": fake.random_int(min=20, max=100),
        "status": fake.random_element(elements=("Normal", "Congested", "Accident")),
    }

while True:
    user = get_registered_users()

    # Convert user data to JSON format
    user_json = json.dumps(user)

    # Produce the message to Kafka
    producer.produce(topic_name, user_json, callback=delivery_report)
    producer.flush()  # Ensure message is sent

    time.sleep(30)
# Out:
# Message delivered to topic Traffic_Updates [partition 1] at offset 15
# Message delivered to topic Traffic_Updates [partition 4] at offset 20
# Message delivered to topic Traffic_Updates [partition 4] at offset 21
# Message delivered to topic Traffic_Updates [partition 0] at offset 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-82869990dbe4> in <cell line: 40>()
#      48     producer.flush()  # Ensure message is sent
#      49
# ---> 50     time.sleep(30)
#
# KeyboardInterrupt:

# %%
import csv
from confluent_kafka import Consumer, KafkaError
import json

bootstrap_servers = 'pkc-7xoy1.eu-central-1.aws.confluent.cloud:9092'
sasl_plain_username = 'ZBQUTRHLZG42QYGL'
sasl_plain_password = 'VQR7ObfHfLQ+aBcUNi00kBynVXpwUq63p6lRk4ZGTtOLwnQWD7mkVIyhcFhaWPpg'
group_id = 'lkc-9pvw9y'
topic_name = 'Traffic_Updates'

csv_file_path = 'received_users.csv'

# Create the Kafka consumer
consumer_config = {
    'bootstrap.servers': bootstrap_servers,
    'group.id': group_id,
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': sasl_plain_username,
    'sasl.password': sasl_plain_password,
    'auto.offset.reset': 'earliest',
}

consumer = Consumer(consumer_config)
consumer.subscribe([topic_name])

try:
    with open(csv_file_path, 'a', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)

        while True:
            msg = consumer.poll(1.0)

            if msg is None:
                continue
            if msg.error():
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    continue
                else:
                    print('Error: {}'.format(msg.error()))
                    break

            try:
                user_json = json.loads(msg.value().decode('utf-8'))
                # Write the user data to the CSV file
                csv_writer.writerow([user_json['name'], user_json['address'], user_json['message'], user_json['created_on']])
                print("Received and recorded user:", user_json)
            except json.JSONDecodeError as e:
                print('Error decoding JSON: {}'.format(e))

except KeyboardInterrupt:
    pass
finally:
    consumer.close()
# Out:
# Received and recorded user: {'name': 'Ryan Mack', 'address': '8946 David Ports Apt. 954\nNorth Dwayneport, VI 14603', 'message': 'Hot particularly day dark one TV. Reduce situation at guess process.\nMeeting increase near who. Pretty hair scene not quality skin under throughout.', 'created_on': '1974'}
# Received and recorded user: {'name': 'Matthew Lane', 'address': '32485 Crawford Cape\nBaldwinshire, CO 93061', 'message': 'Floor cultural ago nature part us. Last first those discover enjoy. Decade road usually moment image.\nBill major all party.', 'created_on': '1986'}
# Received and recorded user: {'name': 'Daniel Castillo', 'address': '112 Nash Course\nWeisshaven, VI 87813', 'message': 'Weight morning nor official worker. New can view through Democrat. Surface yourself interest toward Mrs.\nAdd hear first any everything. Management security different edge gas bed.', 'created_on': '1994'}
# ...

# %%
import time
from faker import Faker
from confluent_kafka import Producer
import json

fake = Faker()

bootstrap_servers = 'pkc-7xoy1.eu-central-1.aws.confluent.cloud:9092'
sasl_plain_username = 'ZBQUTRHLZG42QYGL'
sasl_plain_password = 'VQR7ObfHfLQ+aBcUNi00kBynVXpwUq63p6lRk4ZGTtOLwnQWD7mkVIyhcFhaWPpg'
topic_name = 'Traffic_Updates'

# Create the Kafka producer
producer_config = {
    'bootstrap.servers': bootstrap_servers,
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': sasl_plain_username,
    'sasl.password': sasl_plain_password,
}

producer = Producer(producer_config)


def delivery_report(err, msg):
    if err is not None:
        print('Message delivery failed: {}'.format(err))
    else:
        print('Message delivered to topic {} [partition {}] at offset {}'.format(msg.topic(), msg.partition(), msg.offset()))


def get_registered_users():
    return {
        "name": fake.name(),
        "address": fake.address(),
        "message": fake.text(),
        "created_on": fake.year()
    }

for _ in range(10):
    user = get_registered_users()

    # Convert user data to JSON format
    user_json = json.dumps(user)

    # Produce the message to Kafka
    producer.produce(topic_name, user_json, callback=delivery_report)
    producer.flush()  # Ensure message is sent

    time.sleep(30)


#######################################################################

import csv
from confluent_kafka import Consumer, KafkaError
import json

bootstrap_servers = 'pkc-7xoy1.eu-central-1.aws.confluent.cloud:9092'
sasl_plain_username = 'ZBQUTRHLZG42QYGL'
sasl_plain_password = 'VQR7ObfHfLQ+aBcUNi00kBynVXpwUq63p6lRk4ZGTtOLwnQWD7mkVIyhcFhaWPpg'
group_id = 'lkc-9pvw9y'
topic_name = 'Traffic_Updates'

csv_file_path = 'received_users1.csv'

# Create the Kafka consumer
consumer_config = {
    'bootstrap.servers': bootstrap_servers,
    'group.id': group_id,
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': sasl_plain_username,
    'sasl.password': sasl_plain_password,
    'auto.offset.reset': 'earliest',
}

consumer = Consumer(consumer_config)
consumer.subscribe([topic_name])

try:
    with open(csv_file_path, 'a', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)

        while True:
            msg = consumer.poll(1.0)

            if msg is None:
                continue
            if msg.error():
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    continue
                else:
                    print('Error: {}'.format(msg.error()))
                    break

            try:
                user_json = json.loads(msg.value().decode('utf-8'))
                # Write the user data to the CSV file
                csv_writer.writerow([user_json['name'], user_json['address'], user_json['message'], user_json['created_on']])
                print("Received and recorded user:", user_json)
            except json.JSONDecodeError as e:
                print('Error decoding JSON: {}'.format(e))

except KeyboardInterrupt:
    pass
finally:
    consumer.close()
# Out:
# Message delivered to topic Traffic_Updates [partition 3] at offset 20
# Message delivered to topic Traffic_Updates [partition 3] at offset 21
# Message delivered to topic Traffic_Updates [partition 5] at offset 18
# Message delivered to topic Traffic_Updates [partition 3] at offset 22
# Message delivered to topic Traffic_Updates [partition 4] at offset 22
# Message delivered to topic Traffic_Updates [partition 1] at offset 20
# Message delivered to topic Traffic_Updates [partition 3] at offset 23
# Message delivered to topic Traffic_Updates [partition 3] at offset 24
# Message delivered to topic Traffic_Updates [partition 1] at offset 21
# Message delivered to topic Traffic_Updates [partition 2] at offset 20
# Received and recorded user: {'timestamp': '2024-01-27T14:15:18.821949', 'location': 'D', 'speed': 71, 'status': 'Congested'}
# Received and recorded user: {'timestamp': '2024-01-01T01:12:38.277033', 'location': 'A', 'speed': 85, 'status': 'Accident'}
# ...
